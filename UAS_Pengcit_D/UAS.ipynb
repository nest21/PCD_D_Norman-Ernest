# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('buahuas.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# %%
# Contoh range warna, sesuaikan dengan gambar Anda
lower_red = np.array([0, 100, 100])
upper_red = np.array([10, 255, 255])

lower_green = np.array([35, 100, 100])
upper_green = np.array([85, 255, 255])

lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([30, 255, 255])

# %%
mask_red = cv2.inRange(hsv, lower_red, upper_red)
mask_green = cv2.inRange(hsv, lower_green, upper_green)
mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)

# %%
mask = mask_red + mask_green + mask_yellow

# %%
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
result = image.copy()
cv2.drawContours(result, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [252, 252, 252],
#         [251, 251, 251],
#         [251, 251, 251]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [252, 252, 252],
#         [252, 252, 252],
#         [252, 252, 252]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [254, 254, 254]]], dtype=uint8)

# %%
num_fruits = len(contours)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image)
plt.title('Gambar Asli')
plt.axis('off')

plt.subplot(122)
plt.imshow(result)
plt.title(f'Deteksi Buah: {num_fruits} buah terdeteksi')
plt.axis('off')

plt.tight_layout()
plt.show()
